# %%
import pandas
from astropy.table import Table
from IPython.display import HTML, display

# Import spreadsheet as pandas DataFrame
df = pandas.read_excel('New.xlsx')

# Convert to astropy table
t = Table.from_pandas(df)

# %%
df
# Out:
#                          NAME  FIELD  l (gal)  b (gal)    RA (eq.)  \
# 0   Linear Cluster, Abell 194  01-02  142.066 -62.9999  01 25 40.8
# 1                LGG, NGC 988  02-08  179.933 -58.8207  02 35 27.7
# 2                Fornax Group  03-35   235.97 -54.1523        3.6h
# 3            Eridanus Cluster  03-20   210.49 -53.1273        3.5h
# 4               Doradus Group  04-56  265.823 -43.3838        4.3h
# 5            HIPASS cube H051  05-60  268.748 -37.5303       4:57h
# 6                      HCG 44  10+21  214.401  54.5801       10.3h
# 7               Hydra Cluster  10-27  204.583  51.8363         10h
# 8        Antlia group/cluster  10-35  272.948  19.1874  10 30 03.5
# 9            HIPASS cube H212  11-26  284.505  34.4471    11 44 00
# 10             NGC 3783 group  11-37  286.858  22.7058       11.6h
# 11             Southern Virgo  13-05  306.937  57.8052         13h
# 12             NGC 5044 group  13-10  308.855  52.7042       13.1h
# 13           HIPASS cube H313  13-16  312.207  46.3929       13.3h
# 14                   NGC 5084  13-22  311.753  40.5497  13 20 16.9
# 15                  M83 group  13-32  312.386  30.1628       13.5h
# 16           HIPASS cube H092  13-50  309.422  12.3725    13 31 00
# 17             Circinus field  14-65  311.315  -3.4476       14.2h
# 18              Norma Cluster  16-60  324.529  -5.2906         16h
# 19    HIPASS cube H104 & H143  22-47  350.576 -51.1152         22h
# 20              IC 1459 group  22-36    5.411 -64.7673         23h
# 21                SAMI fields   SAMI      ---      ---         ---
#
#               Dec (eq.) Mean E(B-V) STD E(B-V) STD E(B-V).1  A_g (mag)  \
# 0             -01 24 26      0.0371    0.00864      0.00864   0.140720
# 1                   -8d     0.02797    0.00394      0.00394   0.106090
# 2                  -35d     0.01122    0.00275      0.00275   0.042557
# 3                  -20d      0.0377    0.01498      0.01498   0.142996
# 4                  -56d     0.01362    0.00516      0.00516   0.051661
# 5   1899-12-28 12:30:00    0.021315    0.00568      0.00568   0.080848
# 6                  +21d     0.02521    0.00451      0.00451   0.095622
# 7                  +26d     0.02844    0.00672      0.00672   0.107873
# 8             -35 19 24     0.08287    0.01643      0.01643   0.314326
# 9                   -26     0.06249    0.01527      0.01527   0.237025
# 10               -37.8d     0.10882    0.01647      0.01647   0.412754
# 11                  -5d     0.03079    0.00738      0.00738   0.116786
# 12                 -10d     0.04547    0.00757      0.00757   0.172468
# 13                 -16d     0.07446    0.01157      0.01157   0.282427
# 14            -21 49 39     0.10375    0.01949      0.01949   0.393524
# 15                 -32d     0.05718    0.00696      0.00696   0.216884
# 16                  -50     0.19782    0.07195      0.07195   0.750331
# 17                 -65d      1.5697    1.78679      1.78679   5.953872
# 18                 -60d     0.47092    0.26572      0.26572   1.786200
# 19                 -47d     0.01854     0.0051       0.0051   0.070322
# 20                 -36d    0.015074    0.00256      0.00256   0.057176
# 21                  ---         ---        ---          ---        NaN
#
#     A_r (mag) Mean dust STD dust                          Notes  \
# 0    0.102025    0.0371  0.00864                              "
# 1    0.076917   0.02797  0.00394                      Excellent
# 2    0.030855   0.01122  0.00275                           Best
# 3    0.103675    0.0377  0.01498  strong gradients, not so good
# 4    0.037455   0.01362  0.00516                        Perfect
# 5    0.058616  0.021315  0.00568                              "
# 6    0.069328   0.02521  0.00451                              "
# 7    0.078210   0.02844  0.00672                              "
# 8    0.227892   0.08287  0.01643                            NaN
# 9    0.171847   0.06249  0.01527                            NaN
# 10   0.299255   0.10882  0.01647                            NaN
# 11   0.084672   0.03079  0.00738                              "
# 12   0.125043   0.04547  0.00757                            NaN
# 13   0.204765   0.07446  0.01157                            NaN
# 14   0.285313   0.10375  0.01949                            NaN
# 15   0.157245   0.05718  0.00696                            NaN
# 16   0.544005   0.19782  0.07195                            NaN
# 17   4.316675    1.5697  1.78679                            NaN
# 18   1.295030   0.47092  0.26572                            NaN
# 19   0.050985   0.01854   0.0051                              "
# 20   0.041453  0.015074  0.00256                              "
# 21        NaN       ---      ---                   too distant?
#
#                                       Notes – Extra
# 0                                         Z = 0.018
# 1   1500km/s, Brough et al 2006, Kilborn et al 2009
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                      centre field @ 04:57, -59:30
# 6                                               NaN
# 7                          52Mpc, Gal. Latitude 26d
# 8                                               NaN
# 9                            many HIPASS detections
# 10                                       ~2900 km/s
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15    Centaurus supercluster & Shapley supercluster
# 16                           many HIPASS detections
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                              NaN
# 21                                          Ignored

# %%
t
# Out:
# <Table masked=True length=22>
#            NAME           ...                  Notes – Extra
#           str25           ...                      str47
# ------------------------- ... -----------------------------------------------
# Linear Cluster, Abell 194 ...                                       Z = 0.018
#              LGG, NGC 988 ... 1500km/s, Brough et al 2006, Kilborn et al 2009
#              Fornax Group ...                                              --
#          Eridanus Cluster ...                                              --
#             Doradus Group ...                                              --
#          HIPASS cube H051 ...                    centre field @ 04:57, -59:30
#                    HCG 44 ...                                              --
#             Hydra Cluster ...                        52Mpc, Gal. Latitude 26d
#      Antlia group/cluster ...                                              --
#          HIPASS cube H212 ...                          many HIPASS detections
#            NGC 3783 group ...                                      ~2900 km/s
#            Southern Virgo ...                                              --
#            NGC 5044 group ...                                              --
#          HIPASS cube H313 ...                                              --
#                  NGC 5084 ...                                              --
#                 M83 group ...   Centaurus supercluster & Shapley supercluster
#          HIPASS cube H092 ...                          many HIPASS detections
#            Circinus field ...                                              --
#             Norma Cluster ...                                              --
#   HIPASS cube H104 & H143 ...                                              --
#             IC 1459 group ...                                              --
#               SAMI fields ...                                         Ignored
