# %% [markdown]
# # LOOPING DICE-9

# %% [markdown]
# - Without Random

# %%
import astropy.units as u
from astropy.coordinates import SkyCoord
import math
import itertools

ra='13 37 00'
dec='-29 51 56.74'
ra_dec=SkyCoord('%s %s'%(ra, dec), unit=(u.hourangle,u.deg))
offset=0.5*u.deg
loop=13

def dither_dice5(ra_dec, offset=30*u.arcsec, loop=5):
    if not isinstance(offset,u.Quantity):
        offset=offset*u.arcsec
    """ra_dec=SkyCoord('%s %s'%(ra, dec), unit=(u.hourangle,u.deg))"""
    ra=ra_dec.ra
    dec=ra_dec.dec
    number=math.ceil(loop/9.0)
    
    RA_list=[ra]
    DEC_list=[dec]
    for _ in itertools.repeat(None, number):
        ra1=ra+((0.5*2**0.5)*offset) #0.5*2**0.5 is due to adjacent side in a right angle triangle (cos45)
        RA_list.append(ra1)
        dec1=dec+((0.5*2**0.5)*offset)
        DEC_list.append(dec1)
        
        ra2=ra+((0.5*2**0.5)*offset)
        RA_list.append(ra2)
        DEC_list.append(dec)
        
        ra3=ra+((0.5*2**0.5)*offset)
        RA_list.append(ra3)
        dec3=dec-((0.5*2**0.5)*offset)
        DEC_list.append(dec3)
        
        RA_list.append(ra)
        dec4=dec-((0.5*2**0.5)*offset)
        DEC_list.append(dec4)
        
        ra5=ra-((0.5*2**0.5)*offset)
        RA_list.append(ra5)
        dec5=dec-((0.5*2**0.5)*offset)
        DEC_list.append(dec5)
        
        ra6=ra-((0.5*2**0.5)*offset)
        RA_list.append(ra6)
        DEC_list.append(dec)
        
        ra7=ra-((0.5*2**0.5)*offset)
        RA_list.append(ra7)
        dec7=dec+((0.5*2**0.5)*offset)
        DEC_list.append(dec7)
        
        RA_list.append(ra)
        dec8=dec+((0.5*2**0.5)*offset)
        DEC_list.append(dec8)
        
        
        RA_list.append(ra)
        DEC_list.append(dec)
        
    
    RA_final_list=RA_list[:loop]
    DEC_final_list=DEC_list[:loop]
    All=SkyCoord(RA_final_list,DEC_final_list)
    print (All)
    return All

All=dither_dice5(ra_dec,offset,loop)
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(204.25, -29.86576111), (204.60355339, -29.51220772),
#      (204.60355339, -29.86576111), (204.60355339, -30.2193145),
#      (204.25, -30.2193145), (203.89644661, -30.2193145),
#      (203.89644661, -29.86576111), (203.89644661, -29.51220772),
#      (204.25, -29.51220772), (204.25, -29.86576111),
#      (204.60355339, -29.51220772), (204.60355339, -29.86576111),
#      (204.60355339, -30.2193145)]>

# %% [markdown]
# # LOOPING DICE-5

# %% [markdown]
# - Without Random

# %%
import astropy.units as u
from astropy.coordinates import SkyCoord
import math
import itertools

ra='13 37 00'
dec='-29 51 56.74'
ra_dec=SkyCoord('%s %s'%(ra, dec), unit=(u.hourangle,u.deg))
offset=0.5*u.deg
loop=8

def dither_dice5(ra_dec, offset=30*u.arcsec, loop=5):
    if not isinstance(offset,u.Quantity):
        offset=offset*u.arcsec
    """ra_dec=SkyCoord('%s %s'%(ra, dec), unit=(u.hourangle,u.deg))"""
    ra=ra_dec.ra
    dec=ra_dec.dec
    number=math.ceil(loop/5.0)
    
    RA_list=[ra]
    DEC_list=[dec]
    for _ in itertools.repeat(None, number):
        ra1=ra+((0.5*2**0.5)*offset) #0.5*2**0.5 is due to adjacent side in a right angle triangle (cos45)
        RA_list.append(ra1)
        dec1=dec+((0.5*2**0.5)*offset)
        DEC_list.append(dec1)
        
        ra2=ra+((0.5*2**0.5)*offset)
        RA_list.append(ra2)
        dec2=dec-((0.5*2**0.5)*offset)
        DEC_list.append(dec2)
        
        ra3=ra-((0.5*2**0.5)*offset)
        RA_list.append(ra3)
        dec3=dec-((0.5*2**0.5)*offset)
        DEC_list.append(dec3)
        
        ra4=ra-((0.5*2**0.5)*offset)
        RA_list.append(ra4)
        dec4=dec+((0.5*2**0.5)*offset)
        DEC_list.append(dec4)
        
        RA_list.append(ra)
        DEC_list.append(dec)
        
    
    RA_final_list=RA_list[:loop]
    DEC_final_list=DEC_list[:loop]
    All=SkyCoord(RA_final_list,DEC_final_list)
    print (All)
    return All

All=dither_dice5(ra_dec,offset,loop)
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(204.25, -29.86576111), (204.60355339, -29.51220772),
#      (204.60355339, -30.2193145), (203.89644661, -30.2193145),
#      (203.89644661, -29.51220772), (204.25, -29.86576111),
#      (204.60355339, -29.51220772), (204.60355339, -30.2193145)]>

# %% [markdown]
# # Random For All :)

# %% [markdown]
# - NOTE: Random test done with DICE-9

# %%
import astropy.units as u
from astropy.coordinates import SkyCoord
import itertools
import random
dice_list=All
offset=30*u.arcsec

def dither_dice(dice_list,offset):
    if not isinstance(offset,u.Quantity):
        offset=offset*u.arcsec
    
    RA=[dice_list[0].ra]
    DEC=[dice_list[0].dec]
    for i in range(1,len(dice_list)):
        offset_ra=random.uniform(dice_list[i].ra-(offset*0.5),dice_list[i].ra+(offset*0.5))
        RA.append(offset_ra)
        offset_dec=random.uniform(dice_list[i].dec-(offset*0.5),dice_list[i].dec+(offset*0.5))
        DEC.append(offset_dec)
    
    All=SkyCoord(RA,DEC)
    print (All)
    return All

All=dither_dice(dice_list,offset)
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     [(204.25, -29.86576111), (204.60268532, -29.50921919),
#      (204.60687197, -29.86161337), (204.59958717, -30.21869421),
#      (204.24926044, -30.22201091), (203.89286069, -30.22165402),
#      (203.89308163, -29.8673265), (203.89832583, -29.50840134),
#      (204.25109291, -29.51250335), (204.24726376, -29.86530662),
#      (204.59971734, -29.51458089), (204.60433752, -29.86421221),
#      (204.60573524, -30.21591423)]>
